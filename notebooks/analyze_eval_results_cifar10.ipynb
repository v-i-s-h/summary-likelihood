# %% [markdown]
# # Extract eval results

# %% [markdown]
# Analyze evaluation results for BMNIST with modified $s_0$
# - Clean data

# %%
import sys
sys.path.append("./../")

# %%
import os
import json
import glob
import pickle

import numpy as np
import pandas as pd

# %%
def extract_results(model_dir):
    
    # Get config
    config_json = os.path.join(model_dir, 'config.json')
    config = json.load(open(config_json, 'r'))
    
    # Extract config values
    method = config['method']
    lam_sl = config['method_params'].get('lam_sl', 0.0)
    ds_size = config['ds_params'].get('size', 'Full')
    
    
    results = None
    
    # Get OOD result files
    ood_result_files = glob.glob(model_dir + "/ece_results.pkl")
    
    # Get results
    for rfile in ood_result_files:
        filename = os.path.basename(rfile)
        # Get corruption name from file name
        with open(rfile, 'rb') as f:
            logs = pickle.load(f)[0]
            r = {
                'method': method,
                'lam_sl': lam_sl,
                'ds_size': ds_size,
                'ece': logs['ece_uncal'],
                'acc': logs['acc'],
                'nll': logs['nll_uncal_test'],
                'auroc': logs['auroc']
            }
            
            if results is not None:
                results.append(r)
            else:
                results = [r]
    
    return results

# %% [markdown]
# ## Model dirs

# %%
# models_root = "./../zoo/abl-alpha100-unibin/CIFAR10/VGG11"
models_root = "./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11"
elbo_models_root = "./../zoo/abl-alpha100-unibin-mfvi-cifar10/CIFAR10/VGG11"

# %% [markdown]
# ## S-ELBO results

# %%
model_dirs = list(map(lambda d: os.path.join(models_root, d), os.listdir(models_root)))

# %%
results = []
for _m in model_dirs:
    print(_m)
    results.extend(extract_results(_m))
# Out:
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-02-2-20220728134850
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-02-1-20220728134748
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-04-2-20220728125431
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-05-1-20220728122554
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-04-1-20220728125300
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-03-2-20220728132148
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-04-5-20220728134033
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-04-4-20220728125405
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-01-1-20220728141516
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-06-5-20220728112300
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-01-4-20220728141417
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-03-3-20220728131945
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-05-2-20220728122625
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-05-5-20220728131333
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-06-2-20220728111445
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-06-3-20220728111907
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-03-1-20220728132021
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-01-3-20220728141357
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-05-4-20220728122625
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-06-1-20220728111445
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-05-3-20220728122556
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-03-4-20220728132052
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-02-5-20220728143443
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-06-4-20220728112012
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-01-2-20220728141610
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e+00-1-20220728144251
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-03-5-20220728140732
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e+00-2-20220728144327
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-04-3-20220728125301
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-02-3-20220728134648
# ./../zoo/abl-alpha100-slim-CIFAR10/CIFAR10/VGG11/slim-lam1e-02-4-20220728134745

# %% [markdown]
# ## EBLO results

# %%
model_dirs = list(map(lambda d: os.path.join(elbo_models_root, d), os.listdir(elbo_models_root)))

# %%
for _m in model_dirs:
    results.extend(extract_results(_m))
df_results = pd.DataFrame(results)

# %%
df_results = pd.DataFrame(results)

# %%
df_results
# Out:
#    method    lam_sl ds_size       ece       acc       nll     auroc
# 0    slim  0.010000    Full  0.069834  0.805733  0.673393  0.974516
# 1    slim  0.010000    Full  0.034837  0.797333  0.630910  0.976188
# 2    slim  0.000100    Full  0.107950  0.814933  0.800451  0.975679
# 3    slim  0.000010    Full  0.025263  0.806400  0.609941  0.978025
# 4    slim  0.000100    Full  0.072083  0.809733  0.657443  0.976529
# 5    slim  0.001000    Full  0.104092  0.821333  0.733193  0.978337
# 6    slim  0.000100    Full  0.009465  0.808267  0.592921  0.977695
# 7    slim  0.000100    Full  0.035677  0.800933  0.631788  0.976978
# 8    slim  0.100000    Full  0.033291  0.790933  0.647654  0.973956
# 9    slim  0.000001    Full  0.075332  0.806000  0.667382  0.976297
# 10   slim  0.100000    Full  0.080117  0.775467  0.710997  0.972808
# 11   slim  0.001000    Full  0.081951  0.811333  0.692078  0.975848
# 12   slim  0.000010    Full  0.114470  0.807333  0.793144  0.975987
# 13   slim  0.000010    Full  0.070173  0.813067  0.675769  0.975571
# 14   slim  0.000001    Full  0.103373  0.814800  0.770603  0.976713
# 15   slim  0.000001    Full  0.079605  0.812000  0.666589  0.977557
# 16   slim  0.001000    Full  0.091927  0.800933  0.703003  0.976678
# 17   slim  0.100000    Full  0.015481  0.789200  0.638280  0.974561
# 18   slim  0.000010    Full  0.053035  0.810667  0.634577  0.976047
# 19   slim  0.000001    Full  0.064129  0.807600  0.657581  0.976011
# 20   slim  0.000010    Full  0.090074  0.809467  0.696326  0.977249
# 21   slim  0.001000    Full  0.038820  0.801467  0.650238  0.974938
# 22   slim  0.010000    Full  0.076212  0.752667  0.750948  0.966987
# 23   slim  0.000001    Full  0.056185  0.806000  0.617061  0.977704
# 24   slim  0.100000    Full  0.059413  0.776933  0.749680  0.970019
# 25   slim  1.000000    Full  0.018099  0.132133  2.283138  0.564891
# 26   slim  0.001000    Full  0.059608  0.811067  0.637264  0.976955
# 27   slim  1.000000    Full  0.040091  0.185600  2.127992  0.687272
# 28   slim  0.000100    Full  0.092690  0.812533  0.700274  0.977688
# 29   slim  0.010000    Full  0.044253  0.808400  0.620458  0.977066
# 30   slim  0.010000    Full  0.043785  0.802133  0.612366  0.977393
# 31   mfvi  0.000000    Full  0.059911  0.808933  0.627793  0.976870
# 32   mfvi  0.000000    Full  0.094540  0.816000  0.731362  0.976460
# 33   mfvi  0.000000    Full  0.075172  0.809600  0.658481  0.976977
# 34   mfvi  0.000000    Full  0.079221  0.801200  0.720199  0.974188
# 35   mfvi  0.000000    Full  0.103468  0.810000  0.775703  0.975887

# %%
metrics_summ = df_results.groupby('lam_sl').agg(
    n = pd.NamedAgg(column='acc', aggfunc='count'),
    acc_mean = pd.NamedAgg(column='acc', aggfunc='mean'),
    acc_err = pd.NamedAgg(column='acc', aggfunc=lambda x: np.std(x) / np.sqrt(x.shape[0])),
    ece_mean = pd.NamedAgg(column='ece', aggfunc='mean'),
    ece_err = pd.NamedAgg(column='ece', aggfunc=lambda x: np.std(x) / np.sqrt(x.shape[0])),
    nll_mean = pd.NamedAgg(column='nll', aggfunc='mean'),
    nll_err = pd.NamedAgg(column='nll', aggfunc=lambda x: np.std(x) / np.sqrt(x.shape[0])),
    auroc_mean = pd.NamedAgg(column='auroc', aggfunc='mean'),
    auroc_err = pd.NamedAgg(column='auroc', aggfunc=lambda x: np.std(x) / np.sqrt(x.shape[0])),
)

# %%
metrics_summ
# Out:
#           n  acc_mean   acc_err  ece_mean   ece_err  nll_mean   nll_err  \
# lam_sl
# 0.000000  5  0.809147  0.002108  0.082463  0.006810  0.702708  0.023684
# 0.000001  5  0.809280  0.001577  0.075725  0.007200  0.675843  0.022738
# 0.000010  5  0.809387  0.001064  0.070603  0.013664  0.681951  0.028311
# 0.000100  5  0.809280  0.002130  0.063573  0.016242  0.676575  0.031797
# 0.001000  5  0.809227  0.003367  0.075280  0.010444  0.683155  0.015706
# 0.010000  5  0.793253  0.009226  0.053784  0.007240  0.657615  0.022892
# 0.100000  4  0.783133  0.003490  0.047076  0.012329  0.686653  0.022948
# 1.000000  2  0.158867  0.018903  0.029095  0.007775  2.205565  0.054852
#
#           auroc_mean  auroc_err
# lam_sl
# 0.000000    0.976076   0.000456
# 0.000001    0.976856   0.000300
# 0.000010    0.976576   0.000409
# 0.000100    0.976914   0.000340
# 0.001000    0.976551   0.000509
# 0.010000    0.974430   0.001723
# 0.100000    0.972836   0.000872
# 1.000000    0.626081   0.043268

# %%
metrics_summ = df_results.groupby('lam_sl').agg(
    n = pd.NamedAgg(column='acc', aggfunc='count'),
    acc_mean = pd.NamedAgg(column='acc', aggfunc='mean'),
    acc_err = pd.NamedAgg(column='acc', aggfunc=lambda x: np.std(x) / np.sqrt(x.shape[0])),
    ece_mean = pd.NamedAgg(column='ece', aggfunc='mean'),
    ece_err = pd.NamedAgg(column='ece', aggfunc=lambda x: np.std(x) / np.sqrt(x.shape[0])),
    nll_mean = pd.NamedAgg(column='nll', aggfunc='mean'),
    nll_err = pd.NamedAgg(column='nll', aggfunc=lambda x: np.std(x) / np.sqrt(x.shape[0])),
    auroc_mean = pd.NamedAgg(column='auroc', aggfunc='mean'),
    auroc_err = pd.NamedAgg(column='auroc', aggfunc=lambda x: np.std(x) / np.sqrt(x.shape[0])),
)

# %%
metrics_summ
# Out:
#           n  acc_mean   acc_err  ece_mean   ece_err  nll_mean   nll_err  \
# lam_sl
# 0.000000  5  0.809147  0.002108  0.082463  0.006810  0.702708  0.023684
# 0.000001  5  0.809280  0.001577  0.075725  0.007200  0.675843  0.022738
# 0.000010  5  0.809387  0.001064  0.070603  0.013664  0.681951  0.028311
# 0.000100  5  0.809280  0.002130  0.063573  0.016242  0.676575  0.031797
# 0.001000  5  0.809227  0.003367  0.075280  0.010444  0.683155  0.015706
# 0.010000  5  0.793253  0.009226  0.053784  0.007240  0.657615  0.022892
# 0.100000  4  0.783133  0.003490  0.047076  0.012329  0.686653  0.022948
# 1.000000  2  0.158867  0.018903  0.029095  0.007775  2.205565  0.054852
#
#           auroc_mean  auroc_err
# lam_sl
# 0.000000    0.976076   0.000456
# 0.000001    0.976856   0.000300
# 0.000010    0.976576   0.000409
# 0.000100    0.976914   0.000340
# 0.001000    0.976551   0.000509
# 0.010000    0.974430   0.001723
# 0.100000    0.972836   0.000872
# 1.000000    0.626081   0.043268

# %%
for row in metrics_summ.itertuples():
    print(
        "& ${:.3f} \pm {:.3f}$".format(row.nll_mean, row.nll_err),
        "& ${:.3f} \pm {:.3f}$".format(row.acc_mean, row.acc_err),
#         "& ${:.3f} \pm {:.3f}$".format(row.auroc_mean, row.auroc_err),
        "& ${:.3f} \pm {:.3f}$".format(row.ece_mean, row.ece_err)
    )
# Out:
# & $0.703 \pm 0.024$ & $0.809 \pm 0.002$ & $0.082 \pm 0.007$
# & $0.676 \pm 0.023$ & $0.809 \pm 0.002$ & $0.076 \pm 0.007$
# & $0.682 \pm 0.028$ & $0.809 \pm 0.001$ & $0.071 \pm 0.014$
# & $0.677 \pm 0.032$ & $0.809 \pm 0.002$ & $0.064 \pm 0.016$
# & $0.683 \pm 0.016$ & $0.809 \pm 0.003$ & $0.075 \pm 0.010$
# & $0.658 \pm 0.023$ & $0.793 \pm 0.009$ & $0.054 \pm 0.007$
# & $0.687 \pm 0.023$ & $0.783 \pm 0.003$ & $0.047 \pm 0.012$
# & $2.206 \pm 0.055$ & $0.159 \pm 0.019$ & $0.029 \pm 0.008$
