# %% [markdown]
# # Extract eval results

# %% [markdown]
# Analyze evaluation results for BMNIST with modified $s_0$
# - Clean data

# %%
import sys
sys.path.append("./../")

# %%
import os
import json
import glob
import pickle

import numpy as np
import pandas as pd

# %%
def extract_results(model_dir):
    """
        Get OOD metrics from model dir
    """

    # Get config
    config_json = os.path.join(model_dir, 'config.json')
    config = json.load(open(config_json, 'r'))
    
    # Extract config values
    method = config['method']
    lam_sl = config['method_params'].get('lam_sl', 0.0)
    ds_size = config['ds_params'].get('size', 'Full')
    
    
    results = None
    
    # Get OOD result files
    ood_result_files = glob.glob(model_dir + "/ece_results.pkl")
    
    # Get results
    for rfile in ood_result_files:
        filename = os.path.basename(rfile)
        # Get corruption name from file name
        with open(rfile, 'rb') as f:
            logs = pickle.load(f)[0]
            r = {
                'method': method,
                'lam_sl': lam_sl,
                'ds_size': ds_size,
                'ece': logs['ece_uncal'],
                'acc': logs['acc'],
                'nll': logs['nll_uncal_test'],
                'auroc': logs['auroc']
            }
            
            if results is not None:
                results.append(r)
            else:
                results = [r]
    
    return results

# %% [markdown]
# ## Model dirs

# %%
# LeNet + 1000
# models_root = "./../zoo/abl-a100-mnist-a050b050/BinaryMNISTC-1000-53-identity/LeNet"

# # LeNet + 10000
# models_root = "./../zoo/abl-a100-mnist-a050b050/BinaryMNISTC-10000-53-identity/LeNet"

# # ConvNet + 1000
# models_root = "./../zoo/abl-a100-mnist-a050b050/BinaryMNISTC-1000-53-identity/ConvNet"

# # ConvNet + 10000
models_root = "./../zoo/abl-a100-mnist-a050b050/BinaryMNISTC-10000-53-identity/ConvNet"

# %% [markdown]
# ## S-ELBO results

# %%
model_dirs = list(map(lambda d: os.path.join(models_root, d), os.listdir(models_root)))

# %%
results = []
for _m in model_dirs:
    results.extend(extract_results(_m))

# %%
df_results = pd.DataFrame(results)

# %%
df_results
# Out:
#    method    lam_sl ds_size       ece       acc       nll     auroc
# 0      sl  0.100000    Full  0.174654  0.953749  0.282441  0.992200
# 1      sl  0.000100    Full  0.001475  0.994394  0.018434  0.999761
# 2      sl  0.010000    Full  0.114340  0.985985  0.157406  0.999132
# 3      sl  0.100000    Full  0.101440  0.934828  0.240448  0.987329
# 4      sl  0.001000    Full  0.028824  0.992992  0.045612  0.999622
# 5      sl  0.000010    Full  0.002738  0.997898  0.010346  0.999967
# 6      sl  0.000001    Full  0.002422  0.996496  0.008897  0.999963
# 7      sl  0.010000    Full  0.135422  0.989488  0.178798  0.998762
# 8      sl  0.001000    Full  0.042093  0.993693  0.063582  0.999328
# 9      sl  0.000010    Full  0.000717  0.996496  0.011352  0.999907
# 10     sl  1.000000    Full  0.015245  0.873160  0.292904  0.972528
# 11     sl  0.000010    Full  0.005040  0.994394  0.023693  0.999925
# 12     sl  0.000100    Full  0.004000  0.996496  0.012044  0.999935
# 13     sl  0.100000    Full  0.152286  0.946741  0.266314  0.987824
# 14     sl  0.001000    Full  0.026911  0.992292  0.045078  0.999648
# 15     sl  1.000000    Full  0.037155  0.844429  0.316829  0.948992
# 16     sl  0.000100    Full  0.003237  0.997197  0.011559  0.999939
# 17     sl  0.100000    Full  0.220417  0.948844  0.343813  0.990421
# 18     sl  0.010000    Full  0.096297  0.985985  0.136368  0.998493
# 19     sl  1.000000    Full  0.014274  0.805186  0.402977  0.951824
# 20     sl  0.000010    Full  0.003833  0.996496  0.005909  0.999988
# 21     sl  0.000001    Full  0.000724  0.996496  0.009307  0.999968
# 22     sl  0.100000    Full  0.155015  0.941836  0.272846  0.989862
# 23     sl  0.010000    Full  0.093417  0.981079  0.144966  0.998658
# 24     sl  0.000001    Full  0.001058  0.996496  0.012350  0.999880
# 25     sl  0.001000    Full  0.040745  0.994394  0.058338  0.999690
# 26     sl  0.000010    Full  0.001081  0.995795  0.013124  0.999935
# 27     sl  0.000001    Full  0.003210  0.997197  0.010865  0.999931
# 28     sl  0.001000    Full  0.041592  0.991591  0.064308  0.999286
# 29     sl  1.000000    Full  0.074826  0.887877  0.293914  0.959428
# 30     sl  0.000001    Full  0.002071  0.997197  0.007847  0.999972
# 31     sl  0.000100    Full  0.002298  0.995795  0.009970  0.999953
# 32     sl  1.000000    Full  0.050316  0.811493  0.426003  0.928383
# 33     sl  0.010000    Full  0.099524  0.974772  0.161649  0.996831
# 34     sl  0.000100    Full  0.003390  0.996496  0.013996  0.999890

# %%
metrics_summ = df_results.groupby('lam_sl').agg(
    n = pd.NamedAgg(column='acc', aggfunc='count'),
    acc_mean = pd.NamedAgg(column='acc', aggfunc='mean'),
    acc_err = pd.NamedAgg(column='acc', aggfunc=lambda x: np.std(x) / np.sqrt(x.shape[0])),
    ece_mean = pd.NamedAgg(column='ece', aggfunc='mean'),
    ece_err = pd.NamedAgg(column='ece', aggfunc=lambda x: np.std(x) / np.sqrt(x.shape[0])),
    nll_mean = pd.NamedAgg(column='nll', aggfunc='mean'),
    nll_err = pd.NamedAgg(column='nll', aggfunc=lambda x: np.std(x) / np.sqrt(x.shape[0])),
    auroc_mean = pd.NamedAgg(column='auroc', aggfunc='mean'),
    auroc_err = pd.NamedAgg(column='auroc', aggfunc=lambda x: np.std(x) / np.sqrt(x.shape[0])),
)

# %%
metrics_summ
# Out:
#           n  acc_mean   acc_err  ece_mean   ece_err  nll_mean   nll_err  \
# lam_sl
# 0.000001  5  0.996776  0.000154  0.001897  0.000405  0.009853  0.000707
# 0.000010  5  0.996216  0.000509  0.002682  0.000730  0.012884  0.002641
# 0.000100  5  0.996076  0.000425  0.002880  0.000398  0.013201  0.001304
# 0.001000  5  0.992992  0.000443  0.036033  0.003000  0.055384  0.003780
# 0.010000  5  0.983462  0.002282  0.107800  0.006967  0.155837  0.006514
# 0.100000  5  0.945200  0.002882  0.160763  0.017176  0.281172  0.015329
# 1.000000  5  0.844429  0.014612  0.038363  0.010176  0.346525  0.025321
#
#           auroc_mean  auroc_err
# lam_sl
# 0.000001    0.999943   0.000016
# 0.000010    0.999944   0.000013
# 0.000100    0.999896   0.000031
# 0.001000    0.999514   0.000077
# 0.010000    0.998375   0.000358
# 0.100000    0.989527   0.000795
# 1.000000    0.952231   0.006460

# %%
metrics_summ = df_results.groupby('lam_sl').agg(
    n = pd.NamedAgg(column='acc', aggfunc='count'),
    acc_mean = pd.NamedAgg(column='acc', aggfunc='mean'),
    acc_err = pd.NamedAgg(column='acc', aggfunc=lambda x: np.std(x) / np.sqrt(x.shape[0])),
    ece_mean = pd.NamedAgg(column='ece', aggfunc='mean'),
    ece_err = pd.NamedAgg(column='ece', aggfunc=lambda x: np.std(x) / np.sqrt(x.shape[0])),
    nll_mean = pd.NamedAgg(column='nll', aggfunc='mean'),
    nll_err = pd.NamedAgg(column='nll', aggfunc=lambda x: np.std(x) / np.sqrt(x.shape[0])),
    auroc_mean = pd.NamedAgg(column='auroc', aggfunc='mean'),
    auroc_err = pd.NamedAgg(column='auroc', aggfunc=lambda x: np.std(x) / np.sqrt(x.shape[0])),
)

# %%
metrics_summ
# Out:
#           n  acc_mean   acc_err  ece_mean   ece_err  nll_mean   nll_err  \
# lam_sl
# 0.000001  5  0.996776  0.000154  0.001897  0.000405  0.009853  0.000707
# 0.000010  5  0.996216  0.000509  0.002682  0.000730  0.012884  0.002641
# 0.000100  5  0.996076  0.000425  0.002880  0.000398  0.013201  0.001304
# 0.001000  5  0.992992  0.000443  0.036033  0.003000  0.055384  0.003780
# 0.010000  5  0.983462  0.002282  0.107800  0.006967  0.155837  0.006514
# 0.100000  5  0.945200  0.002882  0.160763  0.017176  0.281172  0.015329
# 1.000000  5  0.844429  0.014612  0.038363  0.010176  0.346525  0.025321
#
#           auroc_mean  auroc_err
# lam_sl
# 0.000001    0.999943   0.000016
# 0.000010    0.999944   0.000013
# 0.000100    0.999896   0.000031
# 0.001000    0.999514   0.000077
# 0.010000    0.998375   0.000358
# 0.100000    0.989527   0.000795
# 1.000000    0.952231   0.006460

# %%
for row in metrics_summ.itertuples():
    print(
        "& ${:.3f} \pm {:.3f}$".format(row.nll_mean, row.nll_err),
        "& ${:.3f} \pm {:.3f}$".format(row.acc_mean, row.acc_err),
#         "& ${:.3f} \pm {:.3f}$".format(row.auroc_mean, row.auroc_err),
        "& ${:.3f} \pm {:.3f}$".format(row.ece_mean, row.ece_err)
    )
# Out:
# & $0.010 \pm 0.001$ & $0.997 \pm 0.000$ & $0.002 \pm 0.000$
# & $0.013 \pm 0.003$ & $0.996 \pm 0.001$ & $0.003 \pm 0.001$
# & $0.013 \pm 0.001$ & $0.996 \pm 0.000$ & $0.003 \pm 0.000$
# & $0.055 \pm 0.004$ & $0.993 \pm 0.000$ & $0.036 \pm 0.003$
# & $0.156 \pm 0.007$ & $0.983 \pm 0.002$ & $0.108 \pm 0.007$
# & $0.281 \pm 0.015$ & $0.945 \pm 0.003$ & $0.161 \pm 0.017$
# & $0.347 \pm 0.025$ & $0.844 \pm 0.015$ & $0.038 \pm 0.010$
